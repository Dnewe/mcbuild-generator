# %%
import yaml
import pprint

CONFIG_PATH = "../conf/parameters.yaml"

# %%
# Print the training config as a dict, to past in kaggle_run.ipynb

config = yaml.load(open(CONFIG_PATH, "r"), Loader=yaml.SafeLoader)
print(config["training"])
# Out:
# {'dataset': {'train_val_split': [0.8, 0.2], 'batch_size': 1, 'num_workers': 0}, 'model': {'use_pretrained': False, 'pretrained_fp': '', 'latent_channels': 64, 'embed_dim': 64, 'pad_block': 'minecraft:air'}, 'loss': {'ce_block_weights': {'air': 0.1, 'dirt': 0.2, 'sand': 0.2, 'water[level=0]': 0.2, 'stone': 0.2, 'diorite': 0.1, 'andesite': 0.1, 'granite': 0.1}, 'kl_start': 0.0, 'kl_end': 1.0, 'kl_anneal_step': 5000}, 'train': {'epochs': 10, 'lr': 0.0001}}

# %%
# Print the validation config as a dict, to past in kaggle_run.ipynb

config = yaml.load(open(CONFIG_PATH, "r"), Loader=yaml.SafeLoader)
pprint.pp(config["validation"], width=70)
# Out:
# {'generate': {'n_builds': 8}, 'reconstruct': {'n_builds': 8}}
