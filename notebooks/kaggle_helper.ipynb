# %%
import yaml
import pprint

CONFIG_PATH = "../conf/parameters.yaml"

# %%
# Print the training config as a dict, to past in kaggle_run.ipynb

config = yaml.load(open(CONFIG_PATH, "r"), Loader=yaml.SafeLoader)
pprint.pp(config["training"], width=70)
# Out:
# {'dataset': {'train_val_split': [0.8, 0.2],
#              'batch_size': 2,
#              'num_workers': 4},
#  'model': {'use_pretrained': False,
#            'pretrained_fp': '',
#            'latent_channels': 128,
#            'embed_dim': 64},
#  'loss': {'air_weight': 0.05,
#           'kl_start': 0.0,
#           'kl_end': 2.0,
#           'kl_anneal_step': 5000},
#  'train': {'epochs': 10, 'lr': 0.003}}
